# %% [markdown]
# **Exercise 1**
# Investigate on the difference between is and == given the following variables.
#
# a = 2
# b = 2.0
# c = a

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# **a** is **c** will evaluate to **True**.#because a and c have both the value  of 2.
#
# **a** is **b** will evaluate to **False**.#b is a decimal number 2.0, which is a different type than integer 2
#
# **a** == **b** will evaluate to **True**.#because a and b have the same numeric value.

# %% [markdown]
# Challenge 1
# Write a program which repeatedly reads numbers until the user enters "done". Once "done" is entered, print out the total, count, and average of the numbers. If the user enters anything other than a number, detect their mistake using try and except and print an error message and skip to the next number.
#
# Enter a number: 4
# Enter a number: 5
# Enter a number: bad data
# Invalid input
# Enter a number: 7
# Enter a number: done
# 16 3 5.333333333333333

# %%
total = 0
count = 0

while True:
    try:
        num_input = input("Enter a number: ")
        if num_input == 'done':
            break
        num = int(num_input)
        total += num
        count += 1
    except ValueError:
        print("Invalid input")

if count > 0:
    average = total / count
    print(total, count, average)
else:
    print("No numbers entered.")
# Out:
# Enter a number: done
# No numbers entered.

# %% [markdown]
# Challenge 2
# Write another program that prompts for a list of numbers as above and at the end prints out both the maximum and minimum of the numbers instead of the average.

# %%
numbers = []

while True:
    num_input = input("Enter a number (or 'done' to finish): ")
    if num_input == 'done':
        break
    try:
        num = float(num_input)
        numbers.append(num)
    except ValueError:
        print("Invalid input")

if numbers:
    max_num = max(numbers)
    min_num = min(numbers)
    print("Maximum:", max_num)
    print("Minimum:", min_num)
else:
    print("No numbers entered.")
# Out:
# Enter a number (or 'done' to finish): 4
# Enter a number (or 'done' to finish): 5
# Enter a number (or 'done' to finish): 6
# Enter a number (or 'done' to finish): 8
# Enter a number (or 'done' to finish): 9
# Enter a number (or 'done' to finish): done
# Maximum: 9.0
# Minimum: 4.0
