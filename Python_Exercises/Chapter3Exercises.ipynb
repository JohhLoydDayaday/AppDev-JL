# %% [markdown]
# **Exercise 1**
# In the code below, which will never print regardless of the value for x? Edit the code to correct the error.
# if x > 0 :
#     print('Above 0')
# elif x >  10 :
#     print('Above 10')
# elif x > 50 :
#     print('Above 50')
# elif x >  20 :
#     print('Above 20')
# else :
#     print('Something else')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
x = int(input("Enter a number: "))
if x > 50 :
  print('Above 50')
elif x >  20 :
  print('Above 20')
elif x > 10 :
  print('Above 10')
elif x >  0 :
  print('Above 0')
else :
  print('Something else')

    #The code never  print  regardless of the value because the conditions are not ordered properly.

# %% [markdown]
# **Exercise 2**
# Write your salary computation to give an employee 1.5 times the hourly rate for hours worked above 40 hours. Example:
#
# Enter Hours: 45
# Enter Rate: 10
# Pay: 475.0

# %%
hours = float(input("Enter Hours: "))
rate = float(input("Enter Rate: "))

if hours > 40:
    reg_pay = 40 * rate
    overt_pay = (hours - 40) * rate * 1.5
    total_pay = reg_pay + overt_pay
else:
    total_pay = hours * rate

print("Pay:", total_pay)
# Out:
# Enter Hours: 45
# Enter Rate: 10
# Pay: 475.0

# %% [markdown]
# **Challenge**
# Write a program to prompt for a score between 0 and 100 and print a grade using the following table:
#
# Score           Grade
# [ 97, 100]      1.0
# [ 93,  96)        1.25
# [ 89,  92)        1.5
# [ 85,  88)        1.75
# [ 81,  84)        2.0
# [ 77,  80)        2.25
# [ 74,  76)        2.5
# [ 0,   73)        3.0

# %%
score = int(input("Enter Score:"))

if (score >= 97  ):
  print("1.0")
elif (score >= 93  ):
  print("1.25")
elif (score >= 89  ):
  print("1.5")
elif (score >= 85 ):
  print("1.75")
elif (score >= 81  ):
  print("2.0")
elif (score >= 77  ):
  print("2.25")
elif (score >= 74  ):
  print("print 2.5")
elif (score >= 0  ):
  print("3.0")
else :
  print("Error")
# Out:
# Enter Score:101
# 1.25
